# %% [markdown]
# #Travel Demand & Destination Recommendation Prediction System

# %% [markdown]
# #Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Load dataset

# %%
df = pd.read_csv("../data/raw/travel_tourism_dataset.csv")

print("Original Shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("travel_tourism_dataset.csv")
#       2
#       3 print("Original Shape:", df.shape)
#
# File ~\OneDrive\Pictures\Desktop\travel-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\OneDrive\Pictures\Desktop\travel-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\OneDrive\Pictures\Desktop\travel-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\OneDrive\Pictures\Desktop\travel-project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\OneDrive\Pictures\Desktop\travel-project\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'travel_tourism_dataset.csv'

# %% [markdown]
# 1. Remove duplicate rows

# %%
print("Duplicate rows before:", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicate rows after:", df.duplicated().sum())
# Out:
# Duplicate rows before: 0
# Duplicate rows after: 0

# %% [markdown]
# 2. Clean column names

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
    .str.replace("/", "_", regex=False)
)

print("\nCleaned Columns:")
print(df.columns.tolist())
# Out:
# Cleaned Columns:
# ['Destination_Name', 'Country', 'Continent', 'Type', 'Avg_Travel_Expense_USD_per_day', 'Best_Season', 'Avg_Temperature_C', 'Avg_Rating', 'Annual_Visitors_M', 'UNESCO_Site']

# %% [markdown]
# 3. Check missing values

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Destination_Name                  0
# Country                           0
# Continent                         0
# Type                              0
# Avg_Travel_Expense_USD_per_day    0
# Best_Season                       0
# Avg_Temperature_C                 0
# Avg_Rating                        0
# Annual_Visitors_M                 0
# UNESCO_Site                       0
# dtype: int64

# %% [markdown]
# 4. Handle missing values

# %%
numeric_columns = df.select_dtypes(
    include=["int64", "float64"]
).columns

categorical_columns = df.select_dtypes(
    include=["object"]
).columns


# Numerical missing values → median
for column in numeric_columns:
    df[column] = df[column].fillna(df[column].median())


# Categorical missing values → mode
for column in categorical_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(df[column].mode()[0])

# %% [markdown]
# 5. Check data types

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Destination_Name                   object
# Country                            object
# Continent                          object
# Type                               object
# Avg_Travel_Expense_USD_per_day    float64
# Best_Season                        object
# Avg_Temperature_C                 float64
# Avg_Rating                        float64
# Annual_Visitors_M                 float64
# UNESCO_Site                        object
# dtype: object

# %% [markdown]
# 6. Identify categorical columns

# %%
print("\nCategorical Columns:")
print(df.select_dtypes(include="object").columns.tolist())
# Out:
# Categorical Columns:
# ['Destination_Name', 'Country', 'Continent', 'Type', 'Best_Season', 'UNESCO_Site']

# %%
df = pd.get_dummies(
    df,
    columns=df.select_dtypes(include="object").columns,
    drop_first=True
)

# %% [markdown]
# 7. Identify numerical columns

# %%
print("\nNumerical Columns:")
print(
    df.select_dtypes(
        include=["int64", "float64"]
    ).columns.tolist()
)
# Out:
# Numerical Columns:
# ['Avg_Travel_Expense_USD_per_day', 'Avg_Temperature_C', 'Avg_Rating', 'Annual_Visitors_M']

# %% [markdown]
# 9. Final missing value check

# %%
print("\nTotal Missing Values:",
      df.isnull().sum().sum())
# Out:
# Total Missing Values: 0

# %% [markdown]
# 10. Final duplicate check

# %%
print("Total Duplicate Rows:",
      df.duplicated().sum())
# Out:
# Total Duplicate Rows: 0

# %% [markdown]
#  11. Save preprocessed dataset

# %%
df.to_csv(
    "travel_tourism_preprocessed.csv",
    index=False
)

print("\n✅ Preprocessing completed successfully!")
print("Final Shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_csv(
#       2     "travel_tourism_preprocessed.csv",
#       3     index=False
#       4 )
#
# NameError: name 'df' is not defined
